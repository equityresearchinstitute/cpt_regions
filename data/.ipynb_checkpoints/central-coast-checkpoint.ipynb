# %%
#importing dependencies
import pandas as pd
import jenkspy
import numpy as np
import json
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in C:\Users\arpitas\AppData\Local\anaconda3\Lib\site-packages (3.1.5)
# Requirement already satisfied: et_xmlfile in C:\Users\arpitas\AppData\Local\anaconda3\Lib\site-packages (from openpyxl) (1.1.0)

# %%
# Read the Excel file into a DataFrame
df = pd.read_csv(r'C:\Users\arpitas\Documents\cpt_local\data\OUT_CSV_MAPDATA_CENTRAL_COAST_V1.CSV')

# %%
# Display the first 5 rows of the DataFrame
df.head()
# Out:
#    UNFORMATTEDAPN          APN  FIPSCODE  \
# 0       908000080  908-000-080      6079
# 1       908000160  908-000-160      6079
# 2       908000003  908-000-003      6079
# 3        39131022  039-131-022      6083
# 4        31152033  031-152-033      6083
#
#                                             ADDRESS           COUNTY  \
# 0                                           , , CA,  SAN LUIS OBISPO
# 1                                           , , CA,  SAN LUIS OBISPO
# 2  765 BRANCH MILL RD, ARROYO GRANDE, CA, 934203504  SAN LUIS OBISPO
# 3       1317 STATE ST, SANTA BARBARA, CA, 931012647    SANTA BARBARA
# 4     220 E ORTEGA ST, SANTA BARBARA, CA, 931011632    SANTA BARBARA
#
#      ZIPCODE ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE
# 0
# 1
# 2  934203504
# 3  931012647                        38.440471953303
# 4  931011632

# %%
df.dtypes
# Out:
# UNFORMATTEDAPN                             int64
# APN                                       object
# FIPSCODE                                   int64
# ADDRESS                                   object
# COUNTY                                    object
# ZIPCODE                                   object
# ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE    object
# dtype: object

# %%
df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] = pd.to_numeric(df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'], errors='coerce')

# %%
print(df.columns.tolist())
# Out:
# ['UNFORMATTEDAPN', 'APN', 'FIPSCODE', 'ADDRESS', 'COUNTY', 'ZIPCODE', 'ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE']

# %%
# Creating legend categories here based on the categories above and input provided by Lenny
conditions = [
    (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] < 15),
    (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] > 15) & (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] <= 35),
    (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] > 35) & (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] <= 60),
    (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] > 60) & (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] <= 100),
    (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] > 100) & (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] <= 250),
    (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] > 250)
]
choices = ['1', '2', '3', '4', '5', '6']
default_value = '0'

# Create the new column using np.select()
df['LEGENDCATEGORY'] = np.select(conditions, choices, default=default_value)

df.head()
# Out:
#    UNFORMATTEDAPN          APN  FIPSCODE  \
# 0       908000080  908-000-080      6079
# 1       908000160  908-000-160      6079
# 2       908000003  908-000-003      6079
# 3        39131022  039-131-022      6083
# 4        31152033  031-152-033      6083
#
#                                             ADDRESS           COUNTY  \
# 0                                           , , CA,  SAN LUIS OBISPO
# 1                                           , , CA,  SAN LUIS OBISPO
# 2  765 BRANCH MILL RD, ARROYO GRANDE, CA, 934203504  SAN LUIS OBISPO
# 3       1317 STATE ST, SANTA BARBARA, CA, 931012647    SANTA BARBARA
# 4     220 E ORTEGA ST, SANTA BARBARA, CA, 931011632    SANTA BARBARA
#
#      ZIPCODE  ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE LEGENDCATEGORY
# 0                                                NaN              0
# 1                                                NaN              0
# 2  934203504                                     NaN              0
# 3  931012647                               38.440472              3
# 4  931011632                                     NaN              0

# %%
df = df.dropna(subset=['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'])
df.head()
# Out:
#    UNFORMATTEDAPN          APN  FIPSCODE  \
# 3        39131022  039-131-022      6083
# 5        85150040  085-150-040      6083
# 6        60252003  060-252-003      6079
# 7       128066006  128-066-006      6083
# 9         3280003  003-280-003      6083
#
#                                             ADDRESS           COUNTY  \
# 3       1317 STATE ST, SANTA BARBARA, CA, 931012647    SANTA BARBARA
# 5            901 E OCEAN AVE, LOMPOC, CA, 934367018    SANTA BARBARA
# 6     1580 W GRAND AVE, GROVER BEACH, CA, 934332261  SAN LUIS OBISPO
# 7       1450 S BROADWAY, SANTA MARIA, CA, 934546914    SANTA BARBARA
# 9  5427 CARPINTERIA AVE, CARPINTERIA, CA, 930131422    SANTA BARBARA
#
#      ZIPCODE  ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE LEGENDCATEGORY
# 3  931012647                               38.440472              3
# 5  934367018                                7.247484              1
# 6  934332261                               29.446363              2
# 7  934546914                                2.346456              1
# 9  930131422                               31.225322              2

# %%
df = df.dropna(how='all')  # drops rows where every column is empty

# %%
print(df.isnull().sum())
# Out:
# UNFORMATTEDAPN                            0
# APN                                       0
# FIPSCODE                                  0
# ADDRESS                                   0
# COUNTY                                    0
# ZIPCODE                                   0
# ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE    0
# LEGENDCATEGORY                            0
# dtype: int64

# %%
df.to_excel('central-coast.xlsx', index=False)

# %%
output = {
    "success": True,
    "data": df.to_dict(orient='records')
}

with open('central-coast.json', 'w') as f:
    json.dump(output, f, indent=2)

print(f"Done! {len(df)} rows converted.")
# Out:
# Done! 33211 rows converted.
