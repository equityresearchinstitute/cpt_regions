# %%
#importing dependencies
import pandas as pd
import jenkspy
import numpy as np
import json
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in C:\Users\arpitas\AppData\Local\anaconda3\Lib\site-packages (3.1.5)
# Requirement already satisfied: et_xmlfile in C:\Users\arpitas\AppData\Local\anaconda3\Lib\site-packages (from openpyxl) (1.1.0)

# %%
# Read the Excel file into a DataFrame
df = pd.read_csv(r'C:\Users\arpitas\Documents\cpt_local\data\OUT_CSV_MAPDATA_INLAND_EMPIRE_V1.CSV')

# %%
# Display the first 5 rows of the DataFrame
df.head()
# Out:
#   UNFORMATTEDAPN               APN  FIPSCODE  ADDRESS          COUNTY ZIPCODE  \
# 0  0543281340000  0543-281-34-0000      6071  , , CA,  SAN BERNARDINO
# 1  0595091070000  0595-091-07-0000      6071  , , CA,  SAN BERNARDINO
# 2  3066051076000  3066-051-07-6000      6071  , , CA,  SAN BERNARDINO
# 3      314270027       314-270-027      6065  , , CA,       RIVERSIDE
# 4   910102101000   910-102-101-000      6025  , , CA,        IMPERIAL
#
#   ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE
# 0                     .00805025463800418
# 1
# 2
# 3                       5.49083117202922
# 4

# %%
df.dtypes
# Out:
# UNFORMATTEDAPN                            object
# APN                                       object
# FIPSCODE                                   int64
# ADDRESS                                   object
# COUNTY                                    object
# ZIPCODE                                   object
# ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE    object
# dtype: object

# %%
df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] = pd.to_numeric(df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'], errors='coerce')

# %%
print(df.columns.tolist())
# Out:
# ['UNFORMATTEDAPN', 'APN', 'FIPSCODE', 'ADDRESS', 'COUNTY', 'ZIPCODE', 'ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE']

# %%
# Creating legend categories here based on the categories above and input provided by Lenny
conditions = [
    (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] < 15),
    (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] > 15) & (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] <= 35),
    (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] > 35) & (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] <= 60),
    (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] > 60) & (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] <= 100),
    (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] > 100) & (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] <= 250),
    (df['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'] > 250)
]
choices = ['1', '2', '3', '4', '5', '6']
default_value = '0'

# Create the new column using np.select()
df['LEGENDCATEGORY'] = np.select(conditions, choices, default=default_value)

df.head()
# Out:
#   UNFORMATTEDAPN               APN  FIPSCODE  ADDRESS          COUNTY ZIPCODE  \
# 0  0543281340000  0543-281-34-0000      6071  , , CA,  SAN BERNARDINO
# 1  0595091070000  0595-091-07-0000      6071  , , CA,  SAN BERNARDINO
# 2  3066051076000  3066-051-07-6000      6071  , , CA,  SAN BERNARDINO
# 3      314270027       314-270-027      6065  , , CA,       RIVERSIDE
# 4   910102101000   910-102-101-000      6025  , , CA,        IMPERIAL
#
#    ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE LEGENDCATEGORY
# 0                                0.008050              1
# 1                                     NaN              0
# 2                                     NaN              0
# 3                                5.490831              1
# 4                                     NaN              0

# %%
df = df.dropna(subset=['ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE'])
df.head()
# Out:
#   UNFORMATTEDAPN               APN  FIPSCODE  \
# 0  0543281340000  0543-281-34-0000      6071
# 3      314270027       314-270-027      6065
# 6  0330055550000  0330-055-55-0000      6071
# 7  0318212080000  0318-212-08-0000      6071
# 8  0350061290000  0350-061-29-0000      6071
#
#                                              ADDRESS          COUNTY  \
# 0                                            , , CA,  SAN BERNARDINO
# 3                                            , , CA,       RIVERSIDE
# 6                   LINDEN LN, CEDAR GLEN, CA, 92321  SAN BERNARDINO
# 7        13682 CALIMESA BLVD, YUCAIPA, CA, 923992356  SAN BERNARDINO
# 8  15750 SWARTHOUT CANYON RD, SAN BERNARDINO, CA,...  SAN BERNARDINO
#
#      ZIPCODE  ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE LEGENDCATEGORY
# 0                                           0.008050              1
# 3                                           5.490831              1
# 6      92321                                1.796364              1
# 7  923992356                                0.216731              1
# 8  924071050                                1.188645              1

# %%
df = df.dropna(how='all')  # drops rows where every column is empty

# %%
print(df.isnull().sum())
# Out:
# UNFORMATTEDAPN                            0
# APN                                       0
# FIPSCODE                                  0
# ADDRESS                                   0
# COUNTY                                    0
# ZIPCODE                                   0
# ASSDLANDVALUEPERTOTALLANDSQUAREFOOTAGE    0
# LEGENDCATEGORY                            0
# dtype: int64

# %%
df.to_excel('inland-empire.xlsx', index=False)

# %%
output = {
    "success": True,
    "data": df.to_dict(orient='records')
}

with open('inland-empire.json', 'w') as f:
    json.dump(output, f, indent=2)

print(f"Done! {len(df)} rows converted.")
# Out:
# Done! 260495 rows converted.
